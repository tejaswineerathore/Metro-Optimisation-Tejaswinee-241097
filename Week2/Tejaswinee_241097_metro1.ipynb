# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lakshmi25npathi/imdb-dataset-of-50k-movie-reviews")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/imdb-dataset-of-50k-movie-reviews

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import nltk

nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df=pd.read_csv("/kaggle/input/imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv")

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# Checking for duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(418)

# %%
df = df.drop_duplicates()

# %% [markdown]
# Checking for null values

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %% [markdown]
# Checking whether the data is balanced or not

# %%
print(df['sentiment'].value_counts())
# Out:
# sentiment
# positive    24884
# negative    24698
# Name: count, dtype: int64

# %% [markdown]
# Check the legth of reviews

# %%
df['text_length'] = df['review'].apply(len)
df['word_count'] = df['review'].apply(lambda x: len(x.split()))

df[['text_length', 'word_count']].describe()
# Out:
# <ipython-input-30-cf7cf95cad47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text_length'] = df['review'].apply(len)
# <ipython-input-30-cf7cf95cad47>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['word_count'] = df['review'].apply(lambda x: len(x.split()))
#         text_length    word_count
# count  49582.000000  49582.000000
# mean    1310.568230    231.350167
# std      990.762238    171.542020
# min       32.000000      4.000000
# 25%      699.000000    126.000000
# 50%      971.000000    173.000000
# 75%     1592.000000    281.000000
# max    13704.000000   2470.000000

# %% [markdown]
# Remove the unwanted elements from the reviews

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r"<.*?>", "", text)
    text = re.sub(r"http\S+|www\S+", "", text)
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return " ".join(words)

df['cleaned_review'] = df['review'].apply(clean_text)
# Out:
# <ipython-input-31-01c8b7834cac>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned_review'] = df['review'].apply(clean_text)

# %% [markdown]
# Displaying the cleaned dataset

# %%
df[['sentiment', 'cleaned_review']].sample(5)
# Out:
#       sentiment                                     cleaned_review
# 49826  positive  tintin one favorite heroes kid used borrow boo...
# 28711  negative  movie give mr bachchan justice great actor dis...
# 37459  positive  truly surprised first saw movie directed iain ...
# 15918  negative  pure crap brief moment thought blond chick goi...
# 40102  positive  basically goofball comedy somewhat odd pacing ...
